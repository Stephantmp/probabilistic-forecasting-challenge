# %%
from functions import get_DAX
from models.DAX import DAX_quantile_regression
from models.DAX import DAX_baseline
from functions.evaluation import evaluate_horizon
from tqdm import tqdm
from functions import evaluate_dax

# %%
# Load data
daxdata= get_DAX.get()

# %%
daxdata
# Out:
#                                    Open          High           Low  \
# Date
# 1988-01-08 00:00:00+01:00   1026.689941   1026.689941   1026.689941
# 1988-01-11 00:00:00+01:00    987.520020    987.520020    987.520020
# 1988-01-12 00:00:00+01:00    986.890015    986.890015    986.890015
# 1988-01-13 00:00:00+01:00    965.770020    965.770020    965.770020
# 1988-01-14 00:00:00+01:00    974.460022    974.460022    974.460022
# ...                                 ...           ...           ...
# 2024-03-04 00:00:00+01:00  17743.439453  17756.390625  17684.730469
# 2024-03-05 00:00:00+01:00  17682.779297  17746.570312  17643.109375
# 2024-03-06 00:00:00+01:00  17685.919922  17745.160156  17682.509766
# 2024-03-07 00:00:00+01:00  17648.890625  17879.109375  17619.400391
# 2024-03-08 00:00:00+01:00  17849.849609  17860.509766  17795.130859
#
#                                   Close    Volume  Dividends  Stock Splits  \
# Date
# ...

# %%
Quant_Reg = DAX_quantile_regression.DAX_quantile_regression(daxdata)
# Out:
# /Users/stephantimpe/PycharmProjects/probabilistic-forecasting-challenge/models/DAX/DAX_quantile_regression.py:26: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pred_quantile_regression[i - 1, j] = res.predict(hist.iloc[-1:])[0]
# /Users/stephantimpe/PycharmProjects/probabilistic-forecasting-challenge/models/DAX/DAX_quantile_regression.py:26: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pred_quantile_regression[i - 1, j] = res.predict(hist.iloc[-1:])[0]
# ...

# %%
print(Quant_Reg)
# Out:
#   forecast_date target horizon    q0.025     q0.25      q0.5     q0.75  \
# 0    2024-03-15    DAX   1 day -2.652792 -0.717995 -0.070455  0.621195
# 1    2024-03-15    DAX   2 day -3.617995 -1.112073 -0.154222  0.910014
# 2    2024-03-15    DAX   3 day -4.343291 -1.396329 -0.235140  1.007154
# 3    2024-03-15    DAX   4 day -4.968020 -1.623541 -0.270024  1.191288
# 4    2024-03-15    DAX   5 day -5.452697 -1.889845 -0.353501  1.312208
#
#      q0.975
# 0  2.857441
# 1  4.065251
# 2  5.020880
# 3  5.838007
# 4  6.435008

# %%
Baseline= DAX_baseline.DAX_baseline(daxdata)

# %%
print(Baseline)
# Out:
#   forecast_date target horizon    q0.025     q0.25      q0.5     q0.75  \
# 0    2024-03-15    DAX   1 day -2.480675 -0.685196 -0.075470  0.491165
# 1    2024-03-15    DAX   2 day -3.392365 -0.951223 -0.105510  0.671254
# 2    2024-03-15    DAX   3 day -4.027670 -1.215024 -0.192477  0.794154
# 3    2024-03-15    DAX   4 day -4.763757 -1.437087 -0.242463  0.849014
# 4    2024-03-15    DAX   5 day -5.019355 -1.553010 -0.377205  0.903051
#
#      q0.975
# 0  2.527232
# 1  3.618075
# 2  4.315379
# 3  5.009079
# 4  5.062647

# %%
baseline_model = {
    'name': 'Baseline Model',
    'function': DAX_baseline.DAX_baseline
}
quantile_model = {
    'name': 'Quantile Regression',
    'function': DAX_quantile_regression.DAX_quantile_regression
}

# %%
start_date = '2023-01-01'
end_date = '2023-01-31'

evaluation_baseline, evaluation_QuantReg= evaluate_dax.evaluate(baseline_model, quantile_model, daxdata, start_date, end_date)
# Out:
# /Users/stephantimpe/PycharmProjects/probabilistic-forecasting-challenge/models/DAX/DAX_quantile_regression.py:26: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pred_quantile_regression[i - 1, j] = res.predict(hist.iloc[-1:])[0]
# /Users/stephantimpe/PycharmProjects/probabilistic-forecasting-challenge/models/DAX/DAX_quantile_regression.py:26: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pred_quantile_regression[i - 1, j] = res.predict(hist.iloc[-1:])[0]
# ...

# %%
print(f"Baseline Model Score: {evaluation_baseline['score'].sum()}")
print(f"Quantile Regression Score: {evaluation_QuantReg['score'].sum()}")
# Out:
# Baseline Model Score: 55.47638475939973
# Quantile Regression Score: 54.46988226083964

# %%
evaluation_baseline
# Out:
#   forecast_date target horizon    q0.025     q0.25      q0.5     q0.75  \
# 0    2023-01-04    DAX   1 day -2.755986 -0.730322 -0.097405  0.538459
# 1    2023-01-04    DAX   2 day -3.570492 -1.006560 -0.132960  0.824250
# 2    2023-01-04    DAX   3 day -4.628697 -1.280589 -0.188963  0.882315
# 3    2023-01-04    DAX   4 day -5.367396 -1.533391 -0.251013  1.024053
# 4    2023-01-04    DAX   5 day -6.259934 -1.651615 -0.392183  1.091646
# 0    2023-01-11    DAX   1 day -2.755986 -0.732738 -0.103579  0.538459
# 1    2023-01-11    DAX   2 day -3.570492 -1.020348 -0.137166  0.824250
# 2    2023-01-11    DAX   3 day -4.628697 -1.302864 -0.198408  0.879535
# 3    2023-01-11    DAX   4 day -5.367396 -1.544448 -0.273944  1.011036
# 4    2023-01-11    DAX   5 day -6.259934 -1.699009 -0.403577  1.070005
# 0    2023-01-18    DAX   1 day -2.755986 -0.731761 -0.105837  0.524205
# 1    2023-01-18    DAX   2 day -3.570492 -1.006560 -0.147857  0.823250
# ...

# %%
import matplotlib.pyplot as plt

# %%
evaluation_baseline.sort_values(by='actual_forecast_date')
# Out:
#   forecast_date target horizon    q0.025     q0.25      q0.5     q0.75  \
# 0    2023-01-04    DAX   1 day -2.755986 -0.730322 -0.097405  0.538459
# 1    2023-01-04    DAX   2 day -3.570492 -1.006560 -0.132960  0.824250
# 2    2023-01-04    DAX   3 day -4.628697 -1.280589 -0.188963  0.882315
# 3    2023-01-04    DAX   4 day -5.367396 -1.533391 -0.251013  1.024053
# 4    2023-01-04    DAX   5 day -6.259934 -1.651615 -0.392183  1.091646
# 0    2023-01-11    DAX   1 day -2.755986 -0.732738 -0.103579  0.538459
# 1    2023-01-11    DAX   2 day -3.570492 -1.020348 -0.137166  0.824250
# 2    2023-01-11    DAX   3 day -4.628697 -1.302864 -0.198408  0.879535
# 3    2023-01-11    DAX   4 day -5.367396 -1.544448 -0.273944  1.011036
# 4    2023-01-11    DAX   5 day -6.259934 -1.699009 -0.403577  1.070005
#
#      q0.975      actual_forecast_date          Open  ...  future_ret3  \
# 0  3.243478 2023-01-05 00:00:00+01:00  14451.230469  ...    -2.316293
# ...
