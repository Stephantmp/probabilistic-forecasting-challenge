# %%
from models.energy import energy_models
from functions import evaluate_energy, get_energy

# %%
energydata = get_energy.get()
# Out:
#   0%|          | 0/273 [00:00<?, ?it/s]/Users/stephantimpe/PycharmProjects/probabilistic-forecasting-challenge/functions/get_energy.py:28: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   energydata = pd.concat([energydata, pd.DataFrame(rawdata, columns=col_names)])
# 100%|██████████| 273/273 [02:57<00:00,  1.54it/s]

# %%
baseline_model = {
    'name': 'Baseline Model',
    'function': energy_models.energy_baseline
}
XGB_model = {
    'name': 'XGBoost',
    'function': energy_models.energy_XGBoost
}
Quantile_model = {
    'name': 'Quantile Regression',
    'function': energy_models.energy_quantile_regression
}
LSTM_model = {
    'name': 'LSTM',
    'function': energy_models.energy_LSTM
}

# %%
start_date = '2022-02-01'
end_date = '2022-04-01'

# Assuming evaluate_energy.evaluate is correctly pointing to the refactored function:
evaluations, grouped_scores = evaluate_energy.evaluate(baseline_model, XGB_model, Quantile_model,LSTM_model, df=energydata, start_date=start_date, end_date=end_date)

# If you need to access individual evaluations, you can do so from the evaluations list:
evaluation_basline = evaluations[0]
evaluation_XGBoost = evaluations[1]
evaluation_QuantReg = evaluations[2]
# Out:
# /Users/stephantimpe/PycharmProjects/probabilistic-forecasting-challenge/models/energy/energy_models.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'] = df.index.month
# /Users/stephantimpe/PycharmProjects/probabilistic-forecasting-challenge/models/energy/energy_models.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['hour'] = df.index.hour
# ...

# %%
evaluation_LSTM = evaluations[3]

# %%
# caluclate the scores
print(sum(evaluation_basline['score']))
print(sum(evaluation_XGBoost['score']))
print(sum(evaluation_QuantReg['score']))
print(sum(evaluation_LSTM['score']))
# Out:
# 220.14291906250003
# 371.2208740997314
# 184.87082635134834
# 385.64841602325436
